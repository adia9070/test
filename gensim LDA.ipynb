# %%
# Gensim
import gensim, spacy, logging, warnings
import gensim.corpora as corpora
from gensim.utils import lemmatize, simple_preprocess
from gensim.models import CoherenceModel
import matplotlib.pyplot as plt
import pandas as pd
from pprint import pprint
import numpy as np
import re
import seaborn as sns
import matplotlib.colors as mcolors
from collections import Counter
from matplotlib.patches import Rectangle
from sklearn.manifold import TSNE
from bokeh.plotting import figure, output_file, show
from bokeh.models import Label
from bokeh.io import output_notebook
from matplotlib import pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import matplotlib.colors as mcolors
from matplotlib.ticker import FuncFormatter
from tqdm import tqdm

# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['br','from', 'subject', 're', 'edu', 'use', 'not', 'would', 'say', 'could', '_', 'be', 'know', 'good', 'go', 'get', 'do', 'done', 'try', 'many', 'some', 'nice', 'thank', 'think', 'see', 'rather', 'easy', 'easily', 'lot', 'lack', 'make', 'want', 'seem', 'run', 'need', 'even', 'right', 'line', 'even', 'also', 'may', 'take', 'come'])

# %matplotlib inline
warnings.filterwarnings("ignore",category=DeprecationWarning)
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

# %%
import time

# %%
df = pd.read_csv('data/imdb.csv')
#df = pd.read_json('data/20newsgroup.json')
#df = df.loc[df.target_names.isin(['soc.religion.christian', 'rec.sport.hockey', 'talk.politics.mideast', 'rec.motorcycles']) , :]
print(df.shape)  #> (2361, 3)
df.head()
# Out:
# (50000, 5)
#    sno  type                                             review label  \
# 0    0  test  Once again Mr. Costner has dragged out a movie...   neg
# 1    1  test  This is an example of why the majority of acti...   neg
# 2    2  test  First of all I hate those moronic rappers, who...   neg
# 3    3  test  Not even the Beatles could write songs everyon...   neg
# 4    4  test  Brass pictures (movies is not a fitting word f...   neg
#
#           file
# 0      0_2.txt
# 1  10000_4.txt
# 2  10001_1.txt
# 3  10002_3.txt
# 4  10003_3.txt

# %%
def sent_to_words(sentences):
    for sent in tqdm(sentences):
        sent = re.sub('\S*@\S*\s?', '', sent)  # remove emails
        sent = re.sub('\s+', ' ', sent)  # remove newline chars
        sent = re.sub("\'", "", sent)  # remove single quotes
        sent = gensim.utils.simple_preprocess(str(sent), deacc=True) 
        yield(sent)  

# Convert to list
#data = df.content.values.tolist()
data = df.review.values.tolist()
data_words = list(sent_to_words(data))
print(data_words[:1])
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 50000/50000 [00:55<00:00, 907.34it/s]
# [['once', 'again', 'mr', 'costner', 'has', 'dragged', 'out', 'movie', 'for', 'far', 'longer', 'than', 'necessary', 'aside', 'from', 'the', 'terrific', 'sea', 'rescue', 'sequences', 'of', 'which', 'there', 'are', 'very', 'few', 'just', 'did', 'not', 'care', 'about', 'any', 'of', 'the', 'characters', 'most', 'of', 'us', 'have', 'ghosts', 'in', 'the', 'closet', 'and', 'costners', 'character', 'are', 'realized', 'early', 'on', 'and', 'then', 'forgotten', 'until', 'much', 'later', 'by', 'which', 'time', 'did', 'not', 'care', 'the', 'character', 'we', 'should', 'really', 'care', 'about', 'is', 'very', 'cocky', 'overconfident', 'ashton', 'kutcher', 'the', 'problem', 'is', 'he', 'comes', 'off', 'as', 'kid', 'who', 'thinks', 'hes', 'better', 'than', 'anyone', 'else', 'around', 'him', 'and', 'shows', 'no', 'signs', 'of', 'cluttered', 'closet', 'his', 'only', 'obstacle', 'appears', 'to', 'be', 'winning', 'over', 'costner', 'finally', 'when', 'we', 'are', 'well', 'past', 'the', 'half', 'way', 'point', 'of', 'this', 'stinker', 'costner', 'tells', 'us', 'all', 'about', 'kutchers', 'ghosts', 'we', 'are', 'told', 'why', 'kutcher', 'is', 'driven', 'to', 'be', 'the', 'best', 'with', 'no', 'prior', 'inkling', 'or', 'foreshadowing', 'no', 'magic', 'here', 'it', 'was', 'all', 'could', 'do', 'to', 'keep', 'from', 'turning', 'it', 'off', 'an', 'hour', 'in']]

# %%
# Build the bigram and trigram models
start = time.time()
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)
print(int(time.time()-start), 'seconds')

def process_words(texts, stop_words=stop_words, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    texts = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in tqdm(texts)]
    texts = [bigram_mod[doc] for doc in tqdm(texts)]
    texts = [trigram_mod[bigram_mod[doc]] for doc in tqdm(texts)]
    
    texts_out = []
    
    nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])
    for sent in tqdm(texts):
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    
    texts_out = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in tqdm(texts_out)]    
    return texts_out

data_ready = process_words(data_words)  # processed Text Data!
# Out:
# 182 seconds
# 100%|███████████████████████████████████████████████████████████████████████████| 50000/50000 [00:53<00:00, 929.05it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 50000/50000 [00:21<00:00, 2292.29it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 50000/50000 [00:42<00:00, 1186.06it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 50000/50000 [07:27<00:00, 111.69it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 50000/50000 [00:31<00:00, 1584.02it/s]

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_ready)

# Create Corpus: Term Document Frequency
corpus = [id2word.doc2bow(text) for text in data_ready]

# %%
print(len(corpus))
# Out:
# 50000

# %%
# Build LDA model
for i in tqdm(range(13,26)):
    lda_model =  gensim.models.ldamulticore.LdaMulticore(corpus=corpus,
                                                         id2word=id2word,
                                                         num_topics=i, 
                                                         random_state=100,
                                                         chunksize=100,
                                                         passes=10,
                                                         alpha='symmetric',
                                                         iterations=10,
                                                         workers=2,
                                                         per_word_topics=True)


    print('Perplexity: ',i, lda_model.log_perplexity(corpus))
    coherence_model_lda = CoherenceModel(model=lda_model, texts=data_ready, dictionary=id2word, coherence='c_v')
    coherence_lda = coherence_model_lda.get_coherence()
    print('Coherence Score: ', i, coherence_lda)
    pprint(lda_model.print_topics())
    print("END\n")
# Out:
#   0%|                                                                                           | 0/13 [00:00<?, ?it/s]
# Perplexity:  13 -10.376986692033551
# Coherence Score:  13 0.40675528720812026
# [(0,
#   '0.023*"people" + 0.016*"war" + 0.015*"american" + 0.014*"world" + '
#   '0.009*"show" + 0.008*"documentary" + 0.008*"history" + 0.008*"country" + '
#   '0.006*"black" + 0.006*"live"'),
#  (1,
#   '0.030*"story" + 0.026*"character" + 0.013*"life" + 0.009*"movie" + '
#   '0.009*"feel" + 0.009*"way" + 0.009*"love" + 0.008*"well" + 0.007*"book" + '
#   '0.007*"time"'),
#  (2,
#   '0.029*"play" + 0.019*"role" + 0.018*"performance" + 0.017*"great" + '
#   '0.014*"actor" + 0.013*"well" + 0.013*"cast" + 0.012*"star" + 0.008*"song" + '
#   '0.007*"give"'),
#  (3,
#   '0.121*"movie" + 0.032*"watch" + 0.022*"time" + 0.021*"great" + '
#   '0.018*"really" + 0.017*"love" + 0.014*"funny" + 0.011*"enjoy" + '
#   '0.011*"people" + 0.010*"well"'),
#  (4,
#   '0.019*"family" + 0.018*"girl" + 0.018*"young" + 0.017*"woman" + '
#   '0.017*"father" + 0.014*"man" + 0.014*"life" + 0.012*"child" + '
#   '0.012*"friend" + 0.011*"son"'),
#  (5,
#   '0.148*"film" + 0.011*"scene" + 0.010*"time" + 0.010*"well" + '
#   '0.009*"director" + 0.009*"work" + 0.008*"much" + 0.006*"plot" + '
#   '0.006*"quite" + 0.006*"first"'),
#  (6,
#   '0.144*"show" + 0.081*"series" + 0.060*"episode" + 0.040*"tv" + 0.036*"game" '
#   '+ 0.025*"season" + 0.020*"television" + 0.014*"first" + 0.014*"cartoon" + '
#   '0.011*"new"'),
#  (7,
#   '0.017*"man" + 0.015*"action" + 0.013*"murder" + 0.012*"kill" + '
#   '0.009*"crime" + 0.009*"hero" + 0.008*"cop" + 0.007*"police" + 0.007*"fight" '
#   '+ 0.006*"western"'),
#  (8,
#   '0.055*"movie" + 0.036*"bad" + 0.017*"really" + 0.015*"act" + 0.014*"plot" + '
#   '0.012*"character" + 0.012*"thing" + 0.012*"look" + 0.011*"end" + '
#   '0.010*"well"'),
#  (9,
#   '0.078*"original" + 0.066*"version" + 0.035*"dvd" + 0.029*"animation" + '
#   '0.022*"voice" + 0.022*"release" + 0.020*"disney" + 0.019*"animate" + '
#   '0.017*"video" + 0.015*"sequel"'),
#  (10,
#   '0.051*"horror" + 0.022*"zombie" + 0.016*"kill" + 0.015*"blood" + '
#   '0.014*"scary" + 0.012*"gore" + 0.011*"dead" + 0.011*"killer" + '
#   '0.010*"creepy" + 0.010*"ghost"'),
#  (11,
#   '0.013*"scene" + 0.011*"look" + 0.009*"back" + 0.009*"man" + 0.008*"car" + '
#   '0.008*"head" + 0.008*"guy" + 0.006*"face" + 0.005*"time" + 0.005*"dog"'),
#  (12,
#   '0.026*"earth" + 0.025*"band" + 0.022*"space" + 0.022*"human" + '
#   '0.020*"sci_fi" + 0.016*"planet" + 0.016*"alien" + 0.013*"animal" + '
#   '0.013*"scientist" + 0.012*"ship"')]
# END
#   8%|██████                                                                         | 1/13 [31:29<6:17:53, 1889.45s/it]
# Perplexity:  14 -10.74313907598339
# Coherence Score:  14 0.39356793006200835
# [(0,
#   '0.020*"thing" + 0.018*"really" + 0.015*"guy" + 0.015*"look" + 0.015*"end" + '
#   '0.013*"people" + 0.013*"scene" + 0.012*"way" + 0.011*"something" + '
#   '0.010*"happen"'),
#  (1,
#   '0.035*"story" + 0.029*"character" + 0.012*"life" + 0.011*"love" + '
#   '0.010*"book" + 0.009*"feel" + 0.008*"way" + 0.006*"end" + 0.006*"time" + '
#   '0.006*"find"'),
#  (2,
#   '0.020*"song" + 0.017*"music" + 0.014*"play" + 0.014*"star" + 0.012*"dance" '
#   '+ 0.010*"year" + 0.009*"musical" + 0.009*"match" + 0.007*"big" + '
#   '0.007*"number"'),
#  (3,
#   '0.054*"show" + 0.032*"series" + 0.032*"funny" + 0.028*"comedy" + '
#   '0.023*"episode" + 0.018*"watch" + 0.015*"tv" + 0.013*"time" + 0.013*"laugh" '
#   '+ 0.012*"first"'),
#  (4,
#   '0.024*"family" + 0.023*"young" + 0.022*"love" + 0.020*"woman" + '
#   '0.020*"girl" + 0.020*"father" + 0.018*"life" + 0.017*"child" + '
#   '0.015*"friend" + 0.015*"man"'),
#  (5,
#   '0.146*"film" + 0.012*"time" + 0.011*"scene" + 0.011*"well" + 0.009*"much" + '
#   '0.009*"work" + 0.008*"director" + 0.007*"first" + 0.006*"quite" + '
#   '0.006*"watch"'),
#  (6,
#   '0.045*"great" + 0.040*"performance" + 0.037*"actor" + 0.035*"play" + '
#   '0.031*"role" + 0.027*"well" + 0.023*"cast" + 0.021*"character" + '
#   '0.018*"act" + 0.017*"excellent"'),
#  (7,
#   '0.018*"man" + 0.007*"kill" + 0.007*"murder" + 0.006*"find" + 0.006*"play" + '
#   '0.006*"action" + 0.005*"crime" + 0.005*"turn" + 0.005*"town" + 0.005*"cop"'),
#  (8,
#   '0.212*"movie" + 0.034*"watch" + 0.021*"time" + 0.018*"really" + '
#   '0.012*"well" + 0.012*"great" + 0.011*"love" + 0.010*"people" + '
#   '0.010*"first" + 0.010*"story"'),
#  (9,
#   '0.066*"bad" + 0.022*"act" + 0.020*"plot" + 0.015*"script" + 0.011*"actor" + '
#   '0.011*"terrible" + 0.011*"waste" + 0.010*"poor" + 0.010*"awful" + '
#   '0.009*"character"'),
#  (10,
#   '0.052*"horror" + 0.017*"zombie" + 0.014*"scary" + 0.013*"blood" + '
#   '0.012*"kill" + 0.012*"gore" + 0.011*"killer" + 0.010*"creepy" + '
#   '0.009*"house" + 0.009*"ghost"'),
#  (11,
#   '0.035*"game" + 0.030*"war" + 0.017*"fight" + 0.015*"soldier" + '
#   '0.014*"battle" + 0.012*"space" + 0.012*"world" + 0.012*"human" + '
#   '0.011*"action" + 0.011*"sci_fi"'),
#  (12,
#   '0.026*"people" + 0.015*"life" + 0.015*"world" + 0.015*"show" + '
#   '0.009*"american" + 0.009*"live" + 0.008*"real" + 0.008*"documentary" + '
#   '0.006*"believe" + 0.006*"history"'),
#  (13,
#   '0.100*"version" + 0.058*"dvd" + 0.053*"black" + 0.044*"original" + '
#   '0.044*"white" + 0.032*"dog" + 0.027*"cat" + 0.026*"release" + '
#   '0.022*"remake" + 0.021*"christmas"')]
# END
#  15%|███████████▊                                                                 | 2/13 [1:02:49<5:45:53, 1886.67s/it]
# Perplexity:  15 -10.92100915179716
# Coherence Score:  15 0.36864711616231666
# [(0,
#   '0.023*"people" + 0.011*"world" + 0.007*"film" + 0.007*"point" + 0.007*"way" '
#   '+ 0.007*"fact" + 0.006*"thing" + 0.006*"documentary" + 0.006*"live" + '
#   '0.005*"life"'),
#  (1,
#   '0.033*"story" + 0.031*"character" + 0.018*"life" + 0.017*"love" + '
#   '0.013*"movie" + 0.010*"feel" + 0.009*"book" + 0.009*"well" + 0.008*"way" + '
#   '0.007*"great"'),
#  (2,
#   '0.030*"play" + 0.025*"great" + 0.020*"role" + 0.017*"performance" + '
#   '0.014*"actor" + 0.013*"star" + 0.013*"cast" + 0.012*"well" + 0.011*"music" '
#   '+ 0.011*"song"'),
#  (3,
#   '0.094*"funny" + 0.085*"comedy" + 0.054*"laugh" + 0.032*"humor" + '
#   '0.026*"joke" + 0.026*"hilarious" + 0.026*"animation" + 0.019*"fun" + '
#   '0.016*"cartoon" + 0.015*"animate"'),
#  (4,
#   '0.021*"girl" + 0.018*"woman" + 0.018*"man" + 0.012*"friend" + 0.011*"find" '
#   '+ 0.011*"young" + 0.010*"wife" + 0.010*"end" + 0.009*"old" + 0.008*"boy"'),
#  (5,
#   '0.138*"film" + 0.013*"well" + 0.012*"scene" + 0.011*"time" + 0.010*"much" + '
#   '0.009*"work" + 0.009*"plot" + 0.008*"director" + 0.007*"really" + '
#   '0.007*"first"'),
#  (6,
#   '0.114*"show" + 0.044*"series" + 0.033*"episode" + 0.029*"tv" + '
#   '0.028*"watch" + 0.020*"game" + 0.019*"first" + 0.017*"time" + '
#   '0.013*"season" + 0.012*"year"'),
#  (7,
#   '0.008*"man" + 0.007*"time" + 0.006*"back" + 0.006*"set" + 0.005*"doctor" + '
#   '0.005*"human" + 0.005*"find" + 0.005*"space" + 0.005*"look" + 0.005*"turn"'),
#  (8,
#   '0.138*"movie" + 0.026*"watch" + 0.022*"really" + 0.019*"bad" + 0.016*"time" '
#   '+ 0.012*"well" + 0.011*"thing" + 0.010*"people" + 0.009*"great" + '
#   '0.009*"act"'),
#  (9,
#   '0.162*"original" + 0.097*"version" + 0.043*"sequel" + 0.036*"batman" + '
#   '0.030*"match" + 0.029*"remake" + 0.027*"favourite" + 0.022*"luke" + '
#   '0.016*"trilogy" + 0.014*"superman"'),
#  (10,
#   '0.049*"horror" + 0.017*"zombie" + 0.014*"scary" + 0.014*"killer" + '
#   '0.013*"blood" + 0.011*"gore" + 0.010*"kill" + 0.010*"flick" + 0.010*"dead" '
#   '+ 0.009*"creepy"'),
#  (11,
#   '0.047*"war" + 0.027*"american" + 0.023*"black" + 0.020*"white" + '
#   '0.018*"western" + 0.017*"man" + 0.017*"country" + 0.016*"soldier" + '
#   '0.013*"german" + 0.013*"show"'),
#  (12,
#   '0.043*"scott" + 0.036*"tom" + 0.034*"sport" + 0.030*"dan" + 0.017*"cup" + '
#   '0.017*"sullivan" + 0.016*"jackson" + 0.014*"manager" + 0.014*"ford" + '
#   '0.014*"simon"'),
#  (13,
#   '0.107*"family" + 0.080*"child" + 0.053*"kid" + 0.029*"father" + 0.028*"son" '
#   '+ 0.027*"adult" + 0.021*"dog" + 0.020*"parent" + 0.015*"mother" + '
#   '0.014*"young"'),
#  (14,
#   '0.031*"action" + 0.029*"scene" + 0.023*"fight" + 0.020*"kill" + 0.019*"guy" '
#   '+ 0.013*"shoot" + 0.013*"hero" + 0.010*"gun" + 0.010*"cop" + 0.010*"car"')]
# END
#  23%|█████████████████▊                                                           | 3/13 [1:35:19<5:17:37, 1905.76s/it]
# Perplexity:  16 -10.857529714715296
# Coherence Score:  16 0.4246900433582756
# [(0,
#   '0.027*"people" + 0.009*"point" + 0.009*"fact" + 0.009*"way" + '
#   '0.008*"character" + 0.008*"thing" + 0.007*"american" + 0.007*"real" + '
#   '0.007*"understand" + 0.007*"show"'),
#  (1,
#   '0.083*"book" + 0.040*"version" + 0.040*"read" + 0.034*"novel" + '
#   '0.027*"story" + 0.017*"adaptation" + 0.012*"passion" + 0.012*"king" + '
#   '0.011*"base" + 0.010*"page"'),
#  (2,
#   '0.033*"play" + 0.021*"role" + 0.015*"performance" + 0.015*"star" + '
#   '0.010*"well" + 0.010*"actor" + 0.010*"cast" + 0.010*"great" + 0.008*"man" + '
#   '0.007*"year"'),
#  (3,
#   '0.089*"funny" + 0.080*"comedy" + 0.040*"laugh" + 0.031*"humor" + '
#   '0.025*"hilarious" + 0.024*"animation" + 0.024*"joke" + 0.019*"fun" + '
#   '0.016*"animate" + 0.016*"disney"'),
#  (4,
#   '0.012*"scene" + 0.010*"end" + 0.010*"guy" + 0.010*"look" + 0.009*"man" + '
#   '0.008*"time" + 0.008*"back" + 0.008*"thing" + 0.008*"way" + 0.007*"start"'),
#  (5,
#   '0.134*"film" + 0.017*"story" + 0.017*"well" + 0.016*"character" + '
#   '0.013*"scene" + 0.011*"much" + 0.010*"time" + 0.009*"great" + 0.008*"plot" '
#   '+ 0.008*"work"'),
#  (6,
#   '0.054*"show" + 0.030*"great" + 0.029*"love" + 0.023*"series" + '
#   '0.022*"watch" + 0.019*"time" + 0.019*"character" + 0.017*"episode" + '
#   '0.014*"first" + 0.014*"tv"'),
#  (7,
#   '0.028*"murder" + 0.022*"black" + 0.022*"crime" + 0.019*"police" + '
#   '0.018*"cop" + 0.013*"white" + 0.012*"criminal" + 0.011*"detective" + '
#   '0.011*"noir" + 0.011*"prison"'),
#  (8,
#   '0.194*"movie" + 0.028*"watch" + 0.022*"really" + 0.017*"time" + '
#   '0.013*"well" + 0.011*"people" + 0.010*"great" + 0.010*"story" + '
#   '0.010*"much" + 0.009*"thing"'),
#  (9,
#   '0.075*"bad" + 0.017*"act" + 0.014*"ever" + 0.014*"script" + 0.013*"plot" + '
#   '0.012*"terrible" + 0.012*"batman" + 0.011*"waste" + 0.011*"look" + '
#   '0.011*"awful"'),
#  (10,
#   '0.047*"horror" + 0.018*"zombie" + 0.013*"kill" + 0.012*"blood" + '
#   '0.012*"scary" + 0.011*"killer" + 0.011*"gore" + 0.011*"sex" + '
#   '0.010*"violence" + 0.009*"dead"'),
#  (11,
#   '0.030*"earth" + 0.024*"space" + 0.024*"human" + 0.022*"sci_fi" + '
#   '0.019*"monster" + 0.018*"animal" + 0.017*"planet" + 0.016*"creature" + '
#   '0.015*"alien" + 0.014*"computer"'),
#  (12,
#   '0.017*"life" + 0.010*"world" + 0.007*"man" + 0.007*"work" + 0.007*"story" + '
#   '0.006*"become" + 0.006*"human" + 0.005*"character" + 0.005*"time" + '
#   '0.005*"experience"'),
#  (13,
#   '0.026*"family" + 0.024*"young" + 0.021*"life" + 0.021*"love" + '
#   '0.021*"child" + 0.021*"father" + 0.019*"woman" + 0.016*"man" + 0.015*"girl" '
#   '+ 0.014*"friend"'),
#  (14,
#   '0.049*"war" + 0.037*"action" + 0.036*"fight" + 0.021*"hero" + '
#   '0.020*"battle" + 0.018*"japanese" + 0.016*"soldier" + 0.013*"german" + '
#   '0.012*"man" + 0.012*"american"'),
#  (15,
#   '0.051*"dvd" + 0.043*"music" + 0.037*"song" + 0.036*"game" + 0.029*"video" + '
#   '0.022*"release" + 0.021*"version" + 0.015*"voice" + 0.015*"copy" + '
#   '0.014*"band"')]
# END
#  31%|███████████████████████▋                                                     | 4/13 [2:08:21<4:49:16, 1928.45s/it]
# Perplexity:  17 -11.015495975571977
# Coherence Score:  17 0.42074109985767644
# [(0,
#   '0.021*"people" + 0.015*"world" + 0.011*"life" + 0.009*"american" + '
#   '0.008*"live" + 0.007*"show" + 0.006*"time" + 0.006*"history" + 0.005*"way" '
#   '+ 0.005*"country"'),
#  (1,
#   '0.042*"character" + 0.036*"story" + 0.019*"love" + 0.016*"life" + '
#   '0.012*"feel" + 0.010*"book" + 0.009*"end" + 0.008*"way" + 0.008*"movie" + '
#   '0.007*"well"'),
#  (2,
#   '0.031*"play" + 0.020*"role" + 0.017*"great" + 0.015*"performance" + '
#   '0.014*"star" + 0.012*"actor" + 0.011*"cast" + 0.011*"song" + 0.010*"love" + '
#   '0.009*"well"'),
#  (3,
#   '0.102*"funny" + 0.090*"comedy" + 0.046*"laugh" + 0.036*"humor" + '
#   '0.028*"joke" + 0.028*"hilarious" + 0.018*"fun" + 0.011*"funniest" + '
#   '0.011*"moment" + 0.010*"comic"'),
#  (4,
#   '0.017*"man" + 0.012*"find" + 0.010*"friend" + 0.009*"back" + 0.009*"end" + '
#   '0.009*"father" + 0.009*"woman" + 0.008*"old" + 0.008*"wife" + 0.008*"home"'),
#  (5,
#   '0.141*"film" + 0.017*"well" + 0.013*"time" + 0.012*"great" + 0.010*"much" + '
#   '0.010*"scene" + 0.009*"really" + 0.008*"story" + 0.008*"work" + '
#   '0.008*"watch"'),
#  (6,
#   '0.096*"show" + 0.038*"series" + 0.030*"episode" + 0.029*"watch" + '
#   '0.026*"tv" + 0.023*"time" + 0.020*"great" + 0.017*"first" + 0.016*"love" + '
#   '0.014*"year"'),
#  (7,
#   '0.016*"murder" + 0.011*"crime" + 0.009*"police" + 0.008*"cop" + '
#   '0.007*"case" + 0.007*"man" + 0.007*"noir" + 0.007*"law" + 0.006*"city" + '
#   '0.006*"prison"'),
#  (8,
#   '0.156*"movie" + 0.027*"watch" + 0.023*"really" + 0.016*"time" + 0.015*"bad" '
#   '+ 0.013*"people" + 0.012*"well" + 0.011*"thing" + 0.011*"great" + '
#   '0.009*"ever"'),
#  (9,
#   '0.020*"bad" + 0.016*"film" + 0.012*"script" + 0.012*"plot" + 0.010*"act" + '
#   '0.010*"look" + 0.010*"director" + 0.008*"scene" + 0.008*"camera" + '
#   '0.008*"character"'),
#  (10,
#   '0.043*"sex" + 0.042*"woman" + 0.038*"scene" + 0.037*"thriller" + '
#   '0.028*"girl" + 0.027*"violence" + 0.022*"female" + 0.017*"sexual" + '
#   '0.014*"male" + 0.014*"rape"'),
#  (11,
#   '0.080*"kid" + 0.072*"child" + 0.052*"family" + 0.033*"boy" + 0.028*"school" '
#   '+ 0.026*"adult" + 0.026*"young" + 0.025*"parent" + 0.024*"girl" + '
#   '0.016*"match"'),
#  (12,
#   '0.024*"president" + 0.024*"science" + 0.017*"moon" + 0.017*"washington" + '
#   '0.014*"jone" + 0.014*"redemption" + 0.012*"grasp" + 0.012*"ford" + '
#   '0.012*"alex" + 0.011*"professor"'),
#  (13,
#   '0.066*"black" + 0.060*"white" + 0.045*"animal" + 0.039*"cat" + '
#   '0.038*"earth" + 0.031*"sci_fi" + 0.028*"dog" + 0.026*"space" + '
#   '0.024*"planet" + 0.024*"race"'),
#  (14,
#   '0.017*"action" + 0.017*"fight" + 0.014*"war" + 0.012*"man" + 0.011*"hero" + '
#   '0.010*"scene" + 0.009*"battle" + 0.008*"soldier" + 0.007*"gun" + '
#   '0.007*"kill"'),
#  (15,
#   '0.070*"horror" + 0.025*"zombie" + 0.020*"scary" + 0.017*"blood" + '
#   '0.016*"gore" + 0.014*"kill" + 0.013*"dead" + 0.013*"monster" + '
#   '0.013*"creepy" + 0.013*"ghost"'),
#  (16,
#   '0.065*"version" + 0.059*"dvd" + 0.047*"game" + 0.041*"original" + '
#   '0.028*"video" + 0.026*"animation" + 0.025*"release" + 0.021*"voice" + '
#   '0.018*"disney" + 0.017*"animate"')]
# END
#  38%|█████████████████████████████▌                                               | 5/13 [2:43:03<4:23:16, 1974.51s/it]
# Perplexity:  18 -11.399158629807612
# Coherence Score:  18 0.41704924052497844
# [(0,
#   '0.020*"people" + 0.014*"world" + 0.011*"show" + 0.010*"american" + '
#   '0.008*"life" + 0.007*"live" + 0.006*"man" + 0.006*"war" + 0.006*"year" + '
#   '0.006*"history"'),
#  (1,
#   '0.049*"story" + 0.035*"character" + 0.030*"love" + 0.020*"life" + '
#   '0.015*"book" + 0.014*"feel" + 0.010*"find" + 0.009*"beautiful" + '
#   '0.009*"way" + 0.008*"true"'),
#  (2,
#   '0.023*"song" + 0.023*"music" + 0.014*"dance" + 0.014*"voice" + '
#   '0.013*"animation" + 0.011*"musical" + 0.010*"star" + 0.009*"band" + '
#   '0.009*"play" + 0.008*"year"'),
#  (3,
#   '0.112*"funny" + 0.101*"comedy" + 0.067*"laugh" + 0.039*"humor" + '
#   '0.033*"joke" + 0.032*"hilarious" + 0.019*"fun" + 0.013*"funniest" + '
#   '0.012*"humour" + 0.011*"moment"'),
#  (4,
#   '0.024*"family" + 0.020*"father" + 0.020*"girl" + 0.019*"kid" + '
#   '0.019*"young" + 0.019*"child" + 0.017*"boy" + 0.015*"friend" + 0.014*"old" '
#   '+ 0.013*"son"'),
#  (5,
#   '0.125*"film" + 0.011*"scene" + 0.011*"time" + 0.010*"much" + 0.009*"well" + '
#   '0.009*"work" + 0.008*"character" + 0.008*"director" + 0.007*"plot" + '
#   '0.007*"first"'),
#  (6,
#   '0.144*"show" + 0.063*"series" + 0.048*"episode" + 0.043*"tv" + '
#   '0.027*"watch" + 0.020*"season" + 0.019*"first" + 0.016*"television" + '
#   '0.015*"time" + 0.010*"new"'),
#  (7,
#   '0.019*"man" + 0.010*"murder" + 0.010*"kill" + 0.009*"find" + 0.008*"play" + '
#   '0.007*"turn" + 0.007*"end" + 0.006*"crime" + 0.005*"cop" + 0.005*"police"'),
#  (8,
#   '0.122*"movie" + 0.026*"watch" + 0.020*"really" + 0.019*"bad" + 0.017*"time" '
#   '+ 0.013*"people" + 0.012*"thing" + 0.009*"end" + 0.009*"ever" + '
#   '0.009*"look"'),
#  (9,
#   '0.061*"original" + 0.025*"bad" + 0.020*"sequel" + 0.019*"script" + '
#   '0.016*"batman" + 0.013*"remake" + 0.012*"poor" + 0.011*"cast" + '
#   '0.010*"special_effect" + 0.009*"new"'),
#  (10,
#   '0.044*"great" + 0.044*"movie" + 0.030*"play" + 0.028*"well" + '
#   '0.027*"performance" + 0.026*"actor" + 0.023*"role" + 0.017*"cast" + '
#   '0.014*"give" + 0.013*"act"'),
#  (11,
#   '0.060*"game" + 0.021*"space" + 0.020*"match" + 0.017*"earth" + '
#   '0.016*"human" + 0.016*"alien" + 0.014*"planet" + 0.013*"ship" + 0.012*"bug" '
#   '+ 0.011*"sci_fi"'),
#  (12,
#   '0.021*"wife" + 0.019*"life" + 0.015*"husband" + 0.012*"dream" + 0.010*"man" '
#   '+ 0.010*"death" + 0.008*"become" + 0.007*"apartment" + 0.007*"question" + '
#   '0.006*"aid"'),
#  (13,
#   '0.095*"black" + 0.094*"white" + 0.063*"documentary" + 0.045*"animal" + '
#   '0.028*"joe" + 0.025*"segment" + 0.022*"interview" + 0.018*"footage" + '
#   '0.016*"science" + 0.013*"environment"'),
#  (14,
#   '0.036*"action" + 0.033*"scene" + 0.031*"fight" + 0.017*"battle" + '
#   '0.016*"hero" + 0.016*"war" + 0.014*"guy" + 0.013*"soldier" + '
#   '0.012*"japanese" + 0.011*"gun"'),
#  (15,
#   '0.058*"horror" + 0.021*"zombie" + 0.016*"blood" + 0.016*"scary" + '
#   '0.014*"monster" + 0.014*"gore" + 0.013*"dead" + 0.013*"kill" + '
#   '0.011*"creepy" + 0.011*"house"'),
#  (16,
#   '0.083*"dvd" + 0.050*"version" + 0.049*"video" + 0.041*"release" + '
#   '0.029*"buy" + 0.025*"copy" + 0.017*"find" + 0.016*"available" + '
#   '0.016*"original" + 0.013*"box"'),
#  (17,
#   '0.076*"woman" + 0.055*"sex" + 0.029*"female" + 0.028*"male" + 0.028*"scene" '
#   '+ 0.027*"sexual" + 0.024*"man" + 0.023*"gay" + 0.021*"girl" + '
#   '0.018*"violence"')]
# END
#  46%|███████████████████████████████████▌                                         | 6/13 [3:18:41<3:56:06, 2023.74s/it]
# Perplexity:  19 -11.321038929621038
# Coherence Score:  19 0.39235633645194384
# [(0,
#   '0.026*"people" + 0.015*"world" + 0.014*"life" + 0.012*"show" + 0.009*"real" '
#   '+ 0.008*"way" + 0.007*"live" + 0.006*"man" + 0.006*"fact" + '
#   '0.006*"documentary"'),
#  (1,
#   '0.043*"character" + 0.038*"story" + 0.013*"end" + 0.013*"well" + '
#   '0.011*"feel" + 0.010*"much" + 0.010*"book" + 0.010*"plot" + 0.009*"way" + '
#   '0.007*"scene"'),
#  (2,
#   '0.034*"play" + 0.024*"role" + 0.023*"performance" + 0.018*"actor" + '
#   '0.017*"great" + 0.015*"cast" + 0.015*"star" + 0.015*"well" + 0.010*"give" + '
#   '0.007*"work"'),
#  (3,
#   '0.080*"show" + 0.042*"series" + 0.034*"comedy" + 0.033*"funny" + '
#   '0.030*"episode" + 0.019*"tv" + 0.015*"laugh" + 0.014*"watch" + '
#   '0.013*"season" + 0.013*"first"'),
#  (4,
#   '0.032*"girl" + 0.031*"woman" + 0.028*"man" + 0.018*"scene" + 0.016*"guy" + '
#   '0.013*"sex" + 0.012*"look" + 0.008*"car" + 0.008*"end" + 0.007*"play"'),
#  (5,
#   '0.010*"time" + 0.010*"scene" + 0.010*"work" + 0.008*"director" + '
#   '0.007*"style" + 0.007*"set" + 0.006*"sequence" + 0.006*"art" + '
#   '0.005*"beautiful" + 0.005*"cinema"'),
#  (6,
#   '0.074*"dog" + 0.064*"king" + 0.063*"cartoon" + 0.038*"lesson" + 0.033*"bug" '
#   '+ 0.023*"lewis" + 0.016*"matt" + 0.015*"pet" + 0.015*"kim" + '
#   '0.015*"stereotypical"'),
#  (7,
#   '0.010*"man" + 0.010*"time" + 0.007*"back" + 0.007*"first" + 0.007*"find" + '
#   '0.006*"world" + 0.006*"new" + 0.005*"match" + 0.005*"send" + '
#   '0.005*"escape"'),
#  (8,
#   '0.045*"movie" + 0.044*"bad" + 0.013*"watch" + 0.013*"act" + 0.012*"really" '
#   '+ 0.012*"thing" + 0.011*"plot" + 0.011*"time" + 0.009*"nothing" + '
#   '0.009*"ever"'),
#  (9,
#   '0.362*"film" + 0.013*"well" + 0.009*"great" + 0.009*"director" + '
#   '0.009*"time" + 0.008*"watch" + 0.008*"scene" + 0.007*"look" + 0.007*"first" '
#   '+ 0.007*"really"'),
#  (10,
#   '0.049*"horror" + 0.016*"kill" + 0.015*"killer" + 0.013*"thriller" + '
#   '0.013*"scary" + 0.011*"blood" + 0.011*"gore" + 0.010*"murder" + '
#   '0.010*"house" + 0.009*"dark"'),
#  (11,
#   '0.084*"war" + 0.046*"american" + 0.034*"black" + 0.031*"western" + '
#   '0.030*"soldier" + 0.025*"white" + 0.023*"japanese" + 0.022*"german" + '
#   '0.021*"indian" + 0.021*"country"'),
#  (12,
#   '0.048*"murder" + 0.047*"crime" + 0.039*"cop" + 0.039*"police" + '
#   '0.024*"criminal" + 0.023*"detective" + 0.019*"noir" + 0.012*"marty" + '
#   '0.012*"mystery" + 0.012*"case"'),
#  (13,
#   '0.024*"life" + 0.024*"family" + 0.018*"father" + 0.017*"love" + '
#   '0.017*"young" + 0.014*"child" + 0.012*"friend" + 0.012*"live" + 0.012*"son" '
#   '+ 0.011*"mother"'),
#  (14,
#   '0.034*"action" + 0.021*"fight" + 0.019*"scene" + 0.017*"look" + '
#   '0.017*"zombie" + 0.011*"kill" + 0.011*"guy" + 0.010*"hero" + 0.009*"shoot" '
#   '+ 0.008*"dead"'),
#  (15,
#   '0.165*"movie" + 0.033*"watch" + 0.028*"great" + 0.023*"really" + '
#   '0.023*"time" + 0.021*"love" + 0.016*"well" + 0.012*"enjoy" + 0.011*"first" '
#   '+ 0.010*"still"'),
#  (16,
#   '0.088*"dvd" + 0.070*"version" + 0.060*"game" + 0.050*"video" + '
#   '0.044*"original" + 0.037*"release" + 0.020*"buy" + 0.018*"copy" + '
#   '0.017*"available" + 0.011*"remake"'),
#  (17,
#   '0.093*"kid" + 0.059*"song" + 0.049*"music" + 0.034*"dance" + '
#   '0.031*"animation" + 0.028*"musical" + 0.026*"voice" + 0.025*"band" + '
#   '0.021*"disney" + 0.019*"adult"'),
#  (18,
#   '0.086*"french" + 0.035*"italian" + 0.027*"spanish" + 0.027*"france" + '
#   '0.023*"realise" + 0.022*"serial" + 0.020*"mexican" + 0.020*"widow" + '
#   '0.019*"brian" + 0.018*"star_trek"')]
# END
#  54%|█████████████████████████████████████████▍                                   | 7/13 [3:55:12<3:27:22, 2073.73s/it]
# Perplexity:  20 -11.466219946778793
# Coherence Score:  20 0.41766601789063545
# [(0,
#   '0.063*"war" + 0.045*"american" + 0.023*"japanese" + 0.021*"country" + '
#   '0.021*"soldier" + 0.017*"german" + 0.015*"indian" + 0.014*"history" + '
#   '0.014*"english" + 0.013*"battle"'),
#  (1,
#   '0.038*"love" + 0.036*"life" + 0.031*"story" + 0.023*"character" + '
#   '0.019*"family" + 0.013*"young" + 0.012*"father" + 0.011*"book" + '
#   '0.010*"relationship" + 0.010*"beautiful"'),
#  (2,
#   '0.034*"play" + 0.024*"role" + 0.021*"performance" + 0.019*"great" + '
#   '0.018*"actor" + 0.016*"star" + 0.015*"cast" + 0.014*"well" + 0.009*"give" + '
#   '0.009*"year"'),
#  (3,
#   '0.097*"funny" + 0.094*"comedy" + 0.058*"laugh" + 0.034*"humor" + '
#   '0.028*"joke" + 0.028*"hilarious" + 0.018*"fun" + 0.012*"funniest" + '
#   '0.010*"moment" + 0.009*"comic"'),
#  (4,
#   '0.015*"man" + 0.013*"find" + 0.012*"end" + 0.011*"woman" + 0.010*"girl" + '
#   '0.010*"friend" + 0.010*"old" + 0.009*"house" + 0.009*"back" + 0.009*"home"'),
#  (5,
#   '0.109*"film" + 0.014*"character" + 0.012*"story" + 0.011*"well" + '
#   '0.011*"scene" + 0.009*"much" + 0.009*"time" + 0.008*"work" + '
#   '0.007*"director" + 0.007*"plot"'),
#  (6,
#   '0.076*"people" + 0.038*"black" + 0.035*"white" + 0.027*"show" + '
#   '0.016*"real" + 0.015*"comment" + 0.012*"talk" + 0.012*"gay" + '
#   '0.010*"review" + 0.009*"critic"'),
#  (7,
#   '0.034*"murder" + 0.027*"crime" + 0.017*"police" + 0.013*"criminal" + '
#   '0.013*"prison" + 0.012*"detective" + 0.012*"noir" + 0.011*"case" + '
#   '0.010*"andy" + 0.010*"cop"'),
#  (8,
#   '0.047*"bad" + 0.036*"movie" + 0.014*"watch" + 0.013*"act" + 0.013*"film" + '
#   '0.012*"ever" + 0.011*"thing" + 0.011*"look" + 0.011*"really" + '
#   '0.010*"plot"'),
#  (9,
#   '0.171*"show" + 0.106*"series" + 0.076*"episode" + 0.045*"tv" + '
#   '0.031*"season" + 0.021*"first" + 0.021*"television" + 0.016*"watch" + '
#   '0.015*"new" + 0.013*"character"'),
#  (10,
#   '0.108*"kid" + 0.049*"child" + 0.047*"girl" + 0.043*"sex" + 0.037*"school" + '
#   '0.036*"adult" + 0.028*"boy" + 0.021*"young" + 0.019*"parent" + '
#   '0.017*"teenager"'),
#  (11,
#   '0.017*"sci_fi" + 0.017*"space" + 0.017*"human" + 0.016*"earth" + '
#   '0.015*"monster" + 0.015*"animal" + 0.013*"alien" + 0.013*"creature" + '
#   '0.012*"planet" + 0.012*"charlie"'),
#  (12,
#   '0.048*"tom" + 0.020*"bully" + 0.018*"cheat" + 0.018*"cook" + 0.017*"homer" '
#   '+ 0.016*"restaurant" + 0.015*"florida" + 0.015*"johnson" + 0.014*"domino" + '
#   '0.014*"nick"'),
#  (13,
#   '0.014*"world" + 0.009*"life" + 0.009*"people" + 0.008*"man" + 0.007*"time" '
#   '+ 0.007*"way" + 0.006*"point" + 0.006*"become" + 0.006*"question" + '
#   '0.005*"human"'),
#  (14,
#   '0.030*"action" + 0.030*"scene" + 0.020*"fight" + 0.018*"guy" + 0.015*"kill" '
#   '+ 0.014*"hero" + 0.013*"man" + 0.013*"shoot" + 0.011*"car" + 0.008*"gun"'),
#  (15,
#   '0.064*"horror" + 0.021*"zombie" + 0.018*"scary" + 0.016*"killer" + '
#   '0.016*"blood" + 0.015*"gore" + 0.014*"kill" + 0.013*"dead" + 0.012*"creepy" '
#   '+ 0.012*"ghost"'),
#  (16,
#   '0.133*"movie" + 0.029*"watch" + 0.023*"really" + 0.023*"great" + '
#   '0.020*"time" + 0.017*"well" + 0.013*"love" + 0.013*"story" + 0.011*"first" '
#   '+ 0.011*"much"'),
#  (17,
#   '0.050*"music" + 0.045*"song" + 0.030*"voice" + 0.028*"dance" + 0.028*"dvd" '
#   '+ 0.027*"version" + 0.025*"animation" + 0.021*"musical" + 0.019*"video" + '
#   '0.018*"band"'),
#  (18,
#   '0.062*"documentary" + 0.042*"city" + 0.021*"youth" + 0.017*"aid" + '
#   '0.017*"segment" + 0.014*"political" + 0.013*"interview" + 0.013*"footage" + '
#   '0.011*"canadian" + 0.010*"urban"'),
#  (19,
#   '0.114*"game" + 0.067*"match" + 0.031*"sport" + 0.018*"team" + '
#   '0.017*"superman" + 0.016*"plane" + 0.015*"win" + 0.014*"bud" + '
#   '0.012*"player" + 0.012*"oil"')]
# END
#  62%|███████████████████████████████████████████████▍                             | 8/13 [5:38:29<4:35:53, 3310.62s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-a51842dee77c> in <module>
#      10                                                          iterations=10,
#      11                                                          workers=2,
# ---> 12                                                          per_word_topics=True)
#      13
#      14
#
# c:\python(3.6.2)\lib\site-packages\gensim\models\ldamulticore.py in __init__(self, corpus, num_topics, id2word, workers, chunksize, passes, batch, alpha, eta, decay, offset, eval_every, iterations, gamma_threshold, random_state, minimum_probability, minimum_phi_value, per_word_topics, dtype)
#     182             decay=decay, offset=offset, eval_every=eval_every, iterations=iterations,
#     183             gamma_threshold=gamma_threshold, random_state=random_state, minimum_probability=minimum_probability,
# --> 184             minimum_phi_value=minimum_phi_value, per_word_topics=per_word_topics, dtype=dtype
#     185         )
#     186
#
# c:\python(3.6.2)\lib\site-packages\gensim\models\ldamodel.py in __init__(self, corpus, num_topics, id2word, distributed, chunksize, passes, update_every, alpha, eta, decay, offset, eval_every, iterations, gamma_threshold, minimum_probability, random_state, ns_conf, minimum_phi_value, per_word_topics, callbacks, dtype)
#     517         if corpus is not None:
#     518             use_numpy = self.dispatcher is not None
# --> 519             self.update(corpus, chunks_as_numpy=use_numpy)
#     520
#     521     def init_dir_prior(self, prior, name):
#
# c:\python(3.6.2)\lib\site-packages\gensim\models\ldamulticore.py in update(self, corpus, chunks_as_numpy)
#     303                         process_result_queue()
#     304
# --> 305                 process_result_queue()
#     306             # endfor single corpus pass
#     307
#
# c:\python(3.6.2)\lib\site-packages\gensim\models\ldamulticore.py in process_result_queue(force)
#     275                 other.reset()
#     276                 if eval_every > 0 and (force or (self.num_updates / updateafter) % eval_every == 0):
# --> 277                     self.log_perplexity(chunk, total_docs=lencorpus)
#     278
#     279         logger.info("training LDA model using %i processes", self.workers)
#
# c:\python(3.6.2)\lib\site-packages\gensim\models\ldamodel.py in log_perplexity(self, chunk, total_docs)
#     819         corpus_words = sum(cnt for document in chunk for _, cnt in document)
#     820         subsample_ratio = 1.0 * total_docs / len(chunk)
# --> 821         perwordbound = self.bound(chunk, subsample_ratio=subsample_ratio) / (subsample_ratio * corpus_words)
#     822         logger.info(
#     823             "%.3f per-word bound, %.1f perplexity estimate based on a held-out corpus of %i documents with %i words",
#
# c:\python(3.6.2)\lib\site-packages\gensim\models\ldamodel.py in bound(self, corpus, gamma, subsample_ratio)
#    1094
#    1095             # E[log p(doc | theta, beta)]
# -> 1096             score += sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
#    1097
#    1098             # E[log p(theta | alpha) - log q(theta | gamma)]; assumes alpha is a vector
#
# c:\python(3.6.2)\lib\site-packages\gensim\models\ldamodel.py in <genexpr>(.0)
#    1094
#    1095             # E[log p(doc | theta, beta)]
# -> 1096             score += sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
#    1097
#    1098             # E[log p(theta | alpha) - log q(theta | gamma)]; assumes alpha is a vector
#
# c:\python(3.6.2)\lib\site-packages\gensim\matutils.py in logsumexp(x)
#    1123
#    1124         """
# -> 1125         x_max = np.max(x)
#    1126         x = np.log(np.sum(np.exp(x - x_max)))
#    1127         x += x_max
#
# c:\python(3.6.2)\lib\site-packages\numpy\core\fromnumeric.py in amax(a, axis, out, keepdims, initial)
#    2503     """
#    2504     return _wrapreduction(a, np.maximum, 'max', axis, None, out, keepdims=keepdims,
# -> 2505                           initial=initial)
#    2506
#    2507
#
# c:\python(3.6.2)\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
# ---> 86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      87
#      88
#
# KeyboardInterrupt:

# %%
def format_topics_sentences(ldamodel=None, corpus=corpus, texts=data):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=data_ready)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic.head(10)

# %%
# 1. Wordcloud of Top N words in each topic
cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'

cloud = WordCloud(stopwords=stop_words,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=10,
                  colormap='tab10',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

topics = lda_model.show_topics(formatted=False)

fig, axes = plt.subplots(2, 2, figsize=(10,10), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i), fontdict=dict(size=16))
    plt.gca().axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()

# %%
topics = lda_model.show_topics(formatted=False)
data_flat = [w for w_list in data_ready for w in w_list]
counter = Counter(data_flat)

out = []
for i, topic in topics:
    for word, weight in topic:
        out.append([word, i , weight, counter[word]])

df = pd.DataFrame(out, columns=['word', 'topic_id', 'importance', 'word_count'])        

# Plot Word Count and Weights of Topic Keywords
fig, axes = plt.subplots(2, 2, figsize=(16,10), sharey=True, dpi=160)
cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]
for i, ax in enumerate(axes.flatten()):
    ax.bar(x='word', height="word_count", data=df.loc[df.topic_id==i, :], color=cols[i], width=0.5, alpha=0.3, label='Word Count')
    ax_twin = ax.twinx()
    ax_twin.bar(x='word', height="importance", data=df.loc[df.topic_id==i, :], color=cols[i], width=0.2, label='Weights')
    ax.set_ylabel('Word Count', color=cols[i])
    ax_twin.set_ylim(0, 0.030); ax.set_ylim(0, 3500)
    ax.set_title('Topic: ' + str(i), color=cols[i], fontsize=16)
    ax.tick_params(axis='y', left=False)
    ax.set_xticklabels(df.loc[df.topic_id==i, 'word'], rotation=30, horizontalalignment= 'right')
    ax.legend(loc='upper left'); ax_twin.legend(loc='upper right')

fig.tight_layout(w_pad=2)    
fig.suptitle('Word Count and Importance of Topic Keywords', fontsize=22, y=1.05)    
plt.show()

# %%
# Plot
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4), dpi=120, sharey=True)

# Topic Distribution by Dominant Topics
ax1.bar(x='Dominant_Topic', height='count', data=df_dominant_topic_in_each_doc, width=.5, color='firebrick')
ax1.set_xticks(range(df_dominant_topic_in_each_doc.Dominant_Topic.unique().__len__()))
tick_formatter = FuncFormatter(lambda x, pos: 'Topic ' + str(x)+ '\n' + df_top3words.loc[df_top3words.topic_id==x, 'words'].values[0])
ax1.xaxis.set_major_formatter(tick_formatter)
ax1.set_title('Number of Documents by Dominant Topic', fontdict=dict(size=10))
ax1.set_ylabel('Number of Documents')
ax1.set_ylim(0, 1000)

# Topic Distribution by Topic Weights
ax2.bar(x='index', height='count', data=df_topic_weightage_by_doc, width=.5, color='steelblue')
ax2.set_xticks(range(df_topic_weightage_by_doc.index.unique().__len__()))
ax2.xaxis.set_major_formatter(tick_formatter)
ax2.set_title('Number of Documents by Topic Weightage', fontdict=dict(size=10))

plt.show()
